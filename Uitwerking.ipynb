# %% [markdown]
# # Importeren van packages

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (7,7) # Make the figures a bit bigger
import tensorflow as tf
from tensorflow import keras

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils

# %% [markdown]
# # Train/Test split

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 3s 0us/step

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# # Distributie van de cijfers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### In Trainset

# %%
train_distribution = plt.hist(y_train, bins=19)
plt.show(train_distribution)

# %% [markdown]
# ### In Testset

# %%
test_distribution = plt.hist(y_test, bins=19)
plt.show(test_distribution)

# %% [markdown]
# # Instantiëren van model Cijfer 1

# %%
y_train_binary = (y_train == 1)
y_test_binary = (y_test == 1)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),  # Flatten 2D input to 1D
    keras.layers.Dense(128, activation='relu'),  # Hidden layer with 128 perceptrons
    keras.layers.Dense(1, activation='sigmoid')  # Output layer with 1 perceptron for binary classification
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Trainen van model Cijfer 1

# %%
model.fit(x_train, y_train_binary, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.0248 - accuracy: 0.9920
# Epoch 2/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0119 - accuracy: 0.9961
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0084 - accuracy: 0.9973
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 5/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 10/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0014 - accuracy: 0.9995

# %% [markdown]
# # Testen van model Cijfer 1

# %%
test_loss, test_acc = model.evaluate(x_test, y_test_binary)
print('Test accuracy:', test_acc * 100)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9974
# Test accuracy: 99.73999857902527

# %% [markdown]
# # Instantiëren van model Cijfer 5

# %%
y_train_digit = (y_train == 5)  # Set True for digit 5, False for other digits
y_test_digit = (y_test == 5)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')  # Output layer with 10 perceptrons for digits 0 to 9
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
y_train_digit = tf.keras.utils.to_categorical(y_train_digit, num_classes=10)
y_test_digit = tf.keras.utils.to_categorical(y_test_digit, num_classes=10)

# %% [markdown]
# # Trainen van model Cijfer 5

# %%
model.fit(x_train, y_train_digit, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.0159 - accuracy: 0.9767
# Epoch 2/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0053 - accuracy: 0.9911
# Epoch 3/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0037 - accuracy: 0.9939
# Epoch 4/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0028 - accuracy: 0.9954
# Epoch 5/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0021 - accuracy: 0.9964
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0017 - accuracy: 0.9974
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0013 - accuracy: 0.9979
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 9.7138e-04 - accuracy: 0.9983
# Epoch 9/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 7.2067e-04 - accuracy: 0.9989
# Epoch 10/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 5.6898e-04 - accuracy: 0.9991

# %% [markdown]
# # Testen van model Cijfer 5

# %%
test_loss, test_acc = model.evaluate(x_test, y_test_digit)
print('Test accuracy:', test_acc * 100)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0030 - accuracy: 0.9950
# Test accuracy: 99.50000047683716

# %% [markdown]
# # Instantiëren van model Alle Cijfers

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)
# Out:
# Training matrix shape (60000, 784)
# Testing matrix shape (10000, 784)

# %%
Y_train = np_utils.to_categorical(y_train, num_classes=10)
Y_test = np_utils.to_categorical(y_test, num_classes=10)

# %%
model = Sequential()
model.add(Dense(512, input_shape=(784,)))
model.add(Activation('relu')) # An "activation" is just a non-linear function applied to the output
                              # of the layer above. Here, with a "rectified linear unit",
                              # we clamp all values below 0 to 0.
                           
model.add(Dropout(0.2))   # Dropout helps protect the model from memorizing or "overfitting" the training data
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(10))
model.add(Activation('softmax')) # This special "softmax" activation among other things,
                                 # ensures the output is a valid probaility distribution, that is
                                 # that its values are all non-negative and sum to 1.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Trainen van model Alle Cijfers

# %%
model.fit(X_train, Y_train,
          batch_size=128, epochs=5,
          verbose=1,
          validation_data=(X_test, Y_test))
# Out:
# Epoch 1/5
# 469/469 [==============================] - 8s 15ms/step - loss: 0.2509 - accuracy: 0.9244 - val_loss: 0.1174 - val_accuracy: 0.9648
# Epoch 2/5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.1017 - accuracy: 0.9685 - val_loss: 0.0779 - val_accuracy: 0.9766
# Epoch 3/5
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0732 - accuracy: 0.9772 - val_loss: 0.0658 - val_accuracy: 0.9787
# Epoch 4/5
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0562 - accuracy: 0.9822 - val_loss: 0.0808 - val_accuracy: 0.9757
# Epoch 5/5
# 469/469 [==============================] - 6s 14ms/step - loss: 0.0455 - accuracy: 0.9855 - val_loss: 0.0678 - val_accuracy: 0.9783

# %% [markdown]
# # Testen van model Alle Cijfers

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], score[1]*100))
# Out:
# accuracy: 97.83%

# %%
# The predict_classes function outputs the highest probability class
# according to the trained classifier for each input example.
predict_x=model.predict(X_test) 
classes_x=np.argmax(predict_x,axis=1)

# Check which items we got right / wrong
correct_indices = np.nonzero(classes_x == y_test)[0]
incorrect_indices = np.nonzero(classes_x != y_test)[0]
# Out:
# 313/313 [==============================] - 2s 5ms/step

# %% [markdown]
# # Juiste/Onjuiste voorspellingen tonen

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(classes_x[correct], y_test[correct]))
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(classes_x[incorrect], y_test[incorrect]))
